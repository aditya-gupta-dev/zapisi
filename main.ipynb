# %%
import polars

# %%
RECORDS_FILE_NAME = "updated_records.csv"

# %%
df = polars.read_csv(RECORDS_FILE_NAME)

# %%
df.columns
# Out:
# ['id',
#  'amount',
#  'currency',
#  'transaction_type',
#  'payment_mode',
#  'official_txn_id',
#  'category',
#  'subcategory',
#  'description',
#  'tags',
#  'linked_loan_id',
#  'loan_status',
#  'amount_remaining',
#  'due_date',
#  'notes',
#  'created_at',
#  'updated_at']
